# %%
#cofig_box
# Out:
# Hello

# %%
# %pip install python-box
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install python-box
# Out:
# ...
#   Using cached python_box-7.4.1-cp313-cp313-win_amd64.whl.metadata (8.3 kB)
# Using cached python_box-7.4.1-cp313-cp313-win_amd64.whl (1.3 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from box import ConfigBox

# %%
dw = ConfigBox({"key1":"valuue1","key2":"valuue2"})

# %%
dw
# Out:
# ConfigBox({'key1': 'valuue1', 'key2': 'valuue2'})

# %%
print(dw.key1)
# Out:
# valuue1

# %%
# %pip install ensure
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ensure import ensure_annotations

# %%
# @ensure_annotations
def predict(x:int,y:int)->int:
    return x*y

# %%
predict(5,"4")
# Out:
# '44444'
