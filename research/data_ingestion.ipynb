# %%
import os

# %%
# %pwd
# Out:
# 'd:\\Arambh\\project\\kedney\\Kidney-Disease-Classification\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\Arambh\\project\\kedney\\Kidney-Disease-Classification'

# %%
from dataclasses import dataclass
from pathlib import Path
from cnnClassifier.constants import *

# %%
@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL:str
    local_data_file: Path
    unzip_dir: Path

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml,create_directorries

# %%
class ConfigurationManger:
    def __init__(
        self ,config_file_path = CONFIG_FILE_PATH,
        params_file_path = PARAMS_FILE_PATH):

        self.config = read_yaml(config_file_path)
        self.params = read_yaml(params_file_path)
        # logger(f"Path : {CONFIG_FILE_PATH}")

        create_directorries([self.config.artifacts_root])
    
    def get_data_ingestion_config(self)->DataIngestionConfig:
        config = self.config.data_ingestion
        create_directorries([config.root_dir])

        data_ingestion_config = DataIngestionConfig(root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir = config.unzip_dir
        )
        return data_ingestion_config

# m = ConfigurationManger()

# %%
#prepare components

import os
import zipfile
import gdown
from cnnClassifier import logger
from cnnClassifier.utils.common import get_size

# from src.cnnClassifier.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self, config:DataIngestionConfig):
        self.config = config
    def downlaod_file(self)->str:
        "fetch data from the url"
        try:
            dataset_url = self.config.source_URL
            zip_download_dir = self.config.local_data_file
            os.makedirs("artifacts/data_ingestion",exist_ok=True)
            logger.info(f"Downloading data form {dataset_url} into file {zip_download_dir}")
            
            file_id = dataset_url.split("/")[-2]
            prefix = 'https://drive.google.com/uc?/export=download&id='   
            gdown.download(prefix+file_id,zip_download_dir)

            logger.info(f"DownLoad data from the {dataset_url} into file {zip_download_dir}")
        except Exception as e:
            raise e
    def extract_zip_file(self):
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path,exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file,'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
try:
    config = ConfigurationManger()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)

    data_ingestion.downlaod_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# [2026-09-07 01:10:59,112: INFO : yaml file config\config.yaml loaded sucessfukky]
# [2026-09-07 01:10:59,113: INFO : content {'artifacts_root': 'artifacts', 'data_ingestion': {'root_dir': 'artifacts/data_ingestion', 'source_URL': 'https://drive.google.com/file/d/1rL6uB6zH8wZWD1rB2yR4povMHWLukq0N/view?usp=sharing', 'local_data_file': 'artifacts/data_ingestion/data.zip', 'unzip_dir': 'artifacts/data_ingestion'}}]
# [2026-09-07 01:10:59,113: INFO : yaml file params.yaml loaded sucessfukky]
# [2026-09-07 01:10:59,114: INFO : content {'key': 'val'}]
# [2026-09-07 01:10:59,114: INFO : create dire ctory at :artifacts]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File box/box.py:605, in box.box.Box.__getitem__()
# --> 605 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'get_data_ingestion'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File box/box.py:644, in box.box.Box.__getattr__()
# --> 644 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:632, in box.box.Box.__getitem__()
# --> 632 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'get_data_ingestion'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File box/box.py:646, in box.box.Box.__getattr__()
# --> 646 'Could not get source, probably due dynamically evaluated source code.'
#
# AttributeError: 'ConfigBox' object has no attribute 'get_data_ingestion'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File box/config_box.py:29, in box.config_box.ConfigBox.__getattr__()
# ---> 29 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:660, in box.box.Box.__getattr__()
# --> 660 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'ConfigBox' object has no attribute 'get_data_ingestion'"
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File box/box.py:605, in box.box.Box.__getitem__()
# --> 605 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'get_data_ingestion'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File box/box.py:644, in box.box.Box.__getattr__()
# --> 644 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:632, in box.box.Box.__getitem__()
# --> 632 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'get_data_ingestion'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File box/box.py:646, in box.box.Box.__getattr__()
# --> 646 'Could not get source, probably due dynamically evaluated source code.'
#
# AttributeError: 'ConfigBox' object has no attribute 'get_data_ingestion'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# Cell In[11], line 9
#       5
#       6     data_ingestion.downlaod_file()
#       7     data_ingestion.extract_zip_file()
#       8 except Exception as e:
# ----> 9     raise e
#
# Cell In[11], line 9
#       5
#       6     data_ingestion.downlaod_file()
#       7     data_ingestion.extract_zip_file()
#       8 except Exception as e:
# ----> 9     raise e
#
# Cell In[8], line 13, in ConfigurationManger.get_data_ingestion_config(self)
#      12     def get_data_ingestion_config(self)->DataIngestionConfig:
# ---> 13         config = self.config.get_data_ingestion
#      14         create_directorries([config.root_dir])
#      15
#      16         data_ingestion_config = DataIngestionConfig(root_dir=config.root_dir,
#
# File box/config_box.py:31, in box.config_box.ConfigBox.__getattr__()
# ---> 31 'Could not get source, probably due dynamically evaluated source code.'
#
# File box/box.py:660, in box.box.Box.__getattr__()
# --> 660 'Could not get source, probably due dynamically evaluated source code.'
#
# BoxKeyError: "'ConfigBox' object has no attribute 'get_data_ingestion'"

# %%
# %ls
# Out:
#  Volume in drive D is New Volume
#  Volume Serial Number is 2E29-9F18
#
#  Directory of d:\Arambh\project\kedney\Kidney-Disease-Classification
#
# 09/06/2026  01:00 AM    <DIR>          .
# 09/06/2026  10:03 PM    <DIR>          ..
# 09/05/2026  11:45 PM    <DIR>          .github
# 09/05/2026  11:45 PM    <DIR>          config
# 09/05/2026  11:47 PM                 0 dvc.yaml
# 09/06/2026  12:39 AM    <DIR>          env
# 09/06/2026  01:00 AM    <DIR>          logs
# 09/06/2026  11:48 AM               386 main.py
# 09/06/2026  10:48 PM                 7 params.yaml
# 09/06/2026  12:22 AM                34 README.md
# 09/06/2026  12:45 AM               194 requirements.txt
# 09/06/2026  10:46 PM    <DIR>          research
# 09/06/2026  12:18 AM               823 setup.py
# 09/06/2026  12:23 AM    <DIR>          src
# 09/05/2026  11:47 PM             1,348 template.py
# 09/05/2026  11:45 PM    <DIR>          templates
# 09/05/2026  11:47 PM                 0 test.py
#                8 File(s)          2,792 bytes
#                9 Dir(s)  126,162,087,936 bytes free
